# %%
import os
import pandas as pd
import numpy as np

# %%
def resample(df):

    # Timedelta index
    df.set_index(pd.to_timedelta(df['time'], unit='s'), inplace=True)
    df.drop(columns=['time'], inplace=True)

    # Resample
    resampled_df = df.resample('20ms').mean()
    resampled_df.interpolate(method='linear', inplace=True)
        
    return resampled_df


def process_folders(inputdir, outputdir, transform):

    # Create output folder
    if not os.path.exists(outputdir):
        os.makedirs(outputdir)
        print(f"Created output folder: {outputdir}")

    for subdirpath, _, filenames in os.walk(inputdir):
        # Create output subfolder
        relativesubdir = os.path.relpath(subdirpath, inputdir)
        outputsubdir = os.path.join(outputdir, relativesubdir)

        if not os.path.exists(outputsubdir):
            os.makedirs(outputsubdir)

        for filename in filenames:
            if filename.endswith(".csv"):
                path_inputfile = os.path.join(subdirpath, filename)
                path_outputfile = os.path.join(outputsubdir, filename)

                print(f"Processing file: {path_inputfile}")
                df = pd.read_csv(path_inputfile)

                # Transform
                processed_df = transform(df)

                # Save
                processed_df.to_csv(path_outputfile, index=False)


def split_folders(inputdir, transformations):

    for outputdir, task in transformations.items():

        # Create
        if not os.path.exists(outputdir):
            os.makedirs(outputdir)
            print(f"Created output folder: {outputdir}")

        for subdirpath, _, filenames in os.walk(inputdir):
            relativesubdir = os.path.relpath(subdirpath, inputdir)
            outputsubdir = os.path.join(outputdir, relativesubdir)

            if not os.path.exists(outputsubdir):
                os.makedirs(outputsubdir)

            for filename in filenames:
                if filename.endswith(".csv"):
                    path_inputfile = os.path.join(subdirpath, filename)
                    path_outputfile = os.path.join(outputsubdir, filename)

                    print(f"Processing {path_inputfile} for {outputdir}")

                    df = pd.read_csv(path_inputfile)
                    required_cols = task['columns']
                        
                    if all(col in df.columns for col in required_cols):
                        new_df = df[required_cols].copy()
                        new_df.rename(columns=task['rename_map'], inplace=True)
                            
                        new_df.to_csv(path_outputfile, index=False)
                    else:
                        print(f"Missing one or more columns")


def flip_signs(df):
    df_flipped = df.copy()
    for col in df_flipped.columns:
        df_flipped[col] = df_flipped[col] * -1
    return df_flipped

def add_one_to_accx(df):
    df_new = df.copy()
    if 'accx' in df_new.columns:
        df_new['accx'] = df_new['accx'] + 1
    return df_new




# ======= DRIVERS =======
def resample_driver():
    inputdir = "Test"
    outputdir = "TestMA50"

    process_folders(inputdir, outputdir, resample)
    print("\nResampling complete.")



def split_driver():
    # --- Splitting Accelrometer and Gyro & remapping the axis ---
    split_input_directory = "TestMA50"
    split_transformations = {
         "TestMA50.acc": {
            "columns": ["az", "ax", "ay"],
            "rename_map": {"ax": "accz", "ay": "accx", "az": "accy"}
        },
        "TestMA50.both": {
            "columns": ["az", "ax", "ay",  "wz", "wx", "wy"],
            "rename_map": {
                "ax": "accz", "ay": "accx", "az": "accy",
                "wx": "gyroz", "wy": "gyrox", "wz": "gyroy"
            }
        }
    }

    split_folders(split_input_directory, split_transformations)
    print("\nSplitting and remapping complete.")





def flip_driver():
    # --- Flipping Signs ---
    flip_transformations = {
        "TestMA50.acc": "TestMA50F.acc",
        "TestMA50.both": "TestMA50F.both"
    }
    
    for input_dir, output_dir in flip_transformations.items():
        print(f"\nFlipping signs for files in '{input_dir}' and saving to '{output_dir}'")
        process_folders(input_dir, output_dir, flip_signs)

    print("\nSign flipping complete.")


    



def range_driver():
    # --- Range transformations ---
    add_one_transformations = {
        "TestMA50F.acc": "TestMA50F.acc.N",
        "TestMA50F.mix": "TestMA50F.mix.N"
    }

    for input_dir, output_dir in add_one_transformations.items():
        print(f"\nAdding 1 to accx for files in '{input_dir}' and saving to '{output_dir}'")
        process_folders(input_dir, output_dir, add_one_to_accx)
            
    print("Range Transforms complete.")


resample_driver()
split_driver()
flip_driver()
range_driver()
# Out:
# Processing file: Test\LAYING\Subject_1.csv
# Processing file: Test\LAYING\Subject_2.csv
# Processing file: Test\LAYING\Subject_3.csv
# Processing file: Test\LAYING\Subject_4.csv
# Processing file: Test\LAYING\Subject_5.csv
# Processing file: Test\LAYING\Subject_6.csv
# Processing file: Test\SITTING\Subject_1.csv
# Processing file: Test\SITTING\Subject_2.csv
# Processing file: Test\SITTING\Subject_3.csv
# Processing file: Test\SITTING\Subject_4.csv
# Processing file: Test\SITTING\Subject_5.csv
# Processing file: Test\SITTING\Subject_6.csv
# Processing file: Test\STANDING\Subject_1.csv
# Processing file: Test\STANDING\Subject_2.csv
# Processing file: Test\STANDING\Subject_3.csv
# Processing file: Test\STANDING\Subject_4.csv
# Processing file: Test\STANDING\Subject_5.csv
# Processing file: Test\STANDING\Subject_6.csv
# Processing file: Test\WALKING\Subject_1.csv
# Processing file: Test\WALKING\Subject_2.csv
# Processing file: Test\WALKING\Subject_3.csv
# Processing file: Test\WALKING\Subject_4.csv
# Processing file: Test\WALKING\Subject_5.csv
# Processing file: Test\WALKING_DOWNSTAIRS\Subject_1.csv
# Processing file: Test\WALKING_DOWNSTAIRS\Subject_2.csv
# Processing file: Test\WALKING_DOWNSTAIRS\Subject_3.csv
# Processing file: Test\WALKING_DOWNSTAIRS\Subject_4.csv
# Processing file: Test\WALKING_DOWNSTAIRS\Subject_5.csv
# Processing file: Test\WALKING_UPSTAIRS\Subject_1.csv
# Processing file: Test\WALKING_UPSTAIRS\Subject_2.csv
# Processing file: Test\WALKING_UPSTAIRS\Subject_3.csv
# Processing file: Test\WALKING_UPSTAIRS\Subject_4.csv
#
# Resampling complete.
# Processing TestMA50\LAYING\Subject_1.csv for TestMA50.acc
# Processing TestMA50\LAYING\Subject_2.csv for TestMA50.acc
# Processing TestMA50\LAYING\Subject_3.csv for TestMA50.acc
# Processing TestMA50\LAYING\Subject_4.csv for TestMA50.acc
# Processing TestMA50\LAYING\Subject_5.csv for TestMA50.acc
# Processing TestMA50\LAYING\Subject_6.csv for TestMA50.acc
# Processing TestMA50\SITTING\Subject_1.csv for TestMA50.acc
# Processing TestMA50\SITTING\Subject_2.csv for TestMA50.acc
# Processing TestMA50\SITTING\Subject_3.csv for TestMA50.acc
# Processing TestMA50\SITTING\Subject_4.csv for TestMA50.acc
# Processing TestMA50\SITTING\Subject_5.csv for TestMA50.acc
# Processing TestMA50\SITTING\Subject_6.csv for TestMA50.acc
# Processing TestMA50\STANDING\Subject_1.csv for TestMA50.acc
# Processing TestMA50\STANDING\Subject_2.csv for TestMA50.acc
# Processing TestMA50\STANDING\Subject_3.csv for TestMA50.acc
# Processing TestMA50\STANDING\Subject_4.csv for TestMA50.acc
# Processing TestMA50\STANDING\Subject_5.csv for TestMA50.acc
# Processing TestMA50\STANDING\Subject_6.csv for TestMA50.acc
# Processing TestMA50\WALKING\Subject_1.csv for TestMA50.acc
# Processing TestMA50\WALKING\Subject_2.csv for TestMA50.acc
# Processing TestMA50\WALKING\Subject_3.csv for TestMA50.acc
# Processing TestMA50\WALKING\Subject_4.csv for TestMA50.acc
# Processing TestMA50\WALKING\Subject_5.csv for TestMA50.acc
# Processing TestMA50\WALKING_DOWNSTAIRS\Subject_1.csv for TestMA50.acc
# Processing TestMA50\WALKING_DOWNSTAIRS\Subject_2.csv for TestMA50.acc
# Processing TestMA50\WALKING_DOWNSTAIRS\Subject_3.csv for TestMA50.acc
# Processing TestMA50\WALKING_DOWNSTAIRS\Subject_4.csv for TestMA50.acc
# Processing TestMA50\WALKING_DOWNSTAIRS\Subject_5.csv for TestMA50.acc
# Processing TestMA50\WALKING_UPSTAIRS\Subject_1.csv for TestMA50.acc
# Processing TestMA50\WALKING_UPSTAIRS\Subject_2.csv for TestMA50.acc
# Processing TestMA50\WALKING_UPSTAIRS\Subject_3.csv for TestMA50.acc
# Processing TestMA50\WALKING_UPSTAIRS\Subject_4.csv for TestMA50.acc
# Processing TestMA50\LAYING\Subject_1.csv for TestMA50.both
# Processing TestMA50\LAYING\Subject_2.csv for TestMA50.both
# Processing TestMA50\LAYING\Subject_3.csv for TestMA50.both
# Processing TestMA50\LAYING\Subject_4.csv for TestMA50.both
# Processing TestMA50\LAYING\Subject_5.csv for TestMA50.both
# Processing TestMA50\LAYING\Subject_6.csv for TestMA50.both
# Processing TestMA50\SITTING\Subject_1.csv for TestMA50.both
# Processing TestMA50\SITTING\Subject_2.csv for TestMA50.both
# Processing TestMA50\SITTING\Subject_3.csv for TestMA50.both
# Processing TestMA50\SITTING\Subject_4.csv for TestMA50.both
# Processing TestMA50\SITTING\Subject_5.csv for TestMA50.both
# Processing TestMA50\SITTING\Subject_6.csv for TestMA50.both
# Processing TestMA50\STANDING\Subject_1.csv for TestMA50.both
# Processing TestMA50\STANDING\Subject_2.csv for TestMA50.both
# Processing TestMA50\STANDING\Subject_3.csv for TestMA50.both
# Processing TestMA50\STANDING\Subject_4.csv for TestMA50.both
# Processing TestMA50\STANDING\Subject_5.csv for TestMA50.both
# Processing TestMA50\STANDING\Subject_6.csv for TestMA50.both
# Processing TestMA50\WALKING\Subject_1.csv for TestMA50.both
# Processing TestMA50\WALKING\Subject_2.csv for TestMA50.both
# Processing TestMA50\WALKING\Subject_3.csv for TestMA50.both
# Processing TestMA50\WALKING\Subject_4.csv for TestMA50.both
# Processing TestMA50\WALKING\Subject_5.csv for TestMA50.both
# Processing TestMA50\WALKING_DOWNSTAIRS\Subject_1.csv for TestMA50.both
# Processing TestMA50\WALKING_DOWNSTAIRS\Subject_2.csv for TestMA50.both
# Processing TestMA50\WALKING_DOWNSTAIRS\Subject_3.csv for TestMA50.both
# Processing TestMA50\WALKING_DOWNSTAIRS\Subject_4.csv for TestMA50.both
# Processing TestMA50\WALKING_DOWNSTAIRS\Subject_5.csv for TestMA50.both
# Processing TestMA50\WALKING_UPSTAIRS\Subject_1.csv for TestMA50.both
# Processing TestMA50\WALKING_UPSTAIRS\Subject_2.csv for TestMA50.both
# Processing TestMA50\WALKING_UPSTAIRS\Subject_3.csv for TestMA50.both
# Processing TestMA50\WALKING_UPSTAIRS\Subject_4.csv for TestMA50.both
#
# Splitting and remapping complete.
#
# Flipping signs for files in 'TestMA50.acc' and saving to 'TestMA50F.acc'
# Processing file: TestMA50.acc\LAYING\Subject_1.csv
# Processing file: TestMA50.acc\LAYING\Subject_2.csv
# Processing file: TestMA50.acc\LAYING\Subject_3.csv
# Processing file: TestMA50.acc\LAYING\Subject_4.csv
# Processing file: TestMA50.acc\LAYING\Subject_5.csv
# Processing file: TestMA50.acc\LAYING\Subject_6.csv
# Processing file: TestMA50.acc\SITTING\Subject_1.csv
# Processing file: TestMA50.acc\SITTING\Subject_2.csv
# Processing file: TestMA50.acc\SITTING\Subject_3.csv
# Processing file: TestMA50.acc\SITTING\Subject_4.csv
# Processing file: TestMA50.acc\SITTING\Subject_5.csv
# Processing file: TestMA50.acc\SITTING\Subject_6.csv
# Processing file: TestMA50.acc\STANDING\Subject_1.csv
# Processing file: TestMA50.acc\STANDING\Subject_2.csv
# Processing file: TestMA50.acc\STANDING\Subject_3.csv
# Processing file: TestMA50.acc\STANDING\Subject_4.csv
# Processing file: TestMA50.acc\STANDING\Subject_5.csv
# Processing file: TestMA50.acc\STANDING\Subject_6.csv
# Processing file: TestMA50.acc\WALKING\Subject_1.csv
# Processing file: TestMA50.acc\WALKING\Subject_2.csv
# Processing file: TestMA50.acc\WALKING\Subject_3.csv
# Processing file: TestMA50.acc\WALKING\Subject_4.csv
# Processing file: TestMA50.acc\WALKING\Subject_5.csv
# Processing file: TestMA50.acc\WALKING_DOWNSTAIRS\Subject_1.csv
# Processing file: TestMA50.acc\WALKING_DOWNSTAIRS\Subject_2.csv
# Processing file: TestMA50.acc\WALKING_DOWNSTAIRS\Subject_3.csv
# Processing file: TestMA50.acc\WALKING_DOWNSTAIRS\Subject_4.csv
# Processing file: TestMA50.acc\WALKING_DOWNSTAIRS\Subject_5.csv
# Processing file: TestMA50.acc\WALKING_UPSTAIRS\Subject_1.csv
# Processing file: TestMA50.acc\WALKING_UPSTAIRS\Subject_2.csv
# Processing file: TestMA50.acc\WALKING_UPSTAIRS\Subject_3.csv
# Processing file: TestMA50.acc\WALKING_UPSTAIRS\Subject_4.csv
#
# Flipping signs for files in 'TestMA50.both' and saving to 'TestMA50F.both'
# Processing file: TestMA50.both\LAYING\Subject_1.csv
# Processing file: TestMA50.both\LAYING\Subject_2.csv
# Processing file: TestMA50.both\LAYING\Subject_3.csv
# Processing file: TestMA50.both\LAYING\Subject_4.csv
# Processing file: TestMA50.both\LAYING\Subject_5.csv
# Processing file: TestMA50.both\LAYING\Subject_6.csv
# Processing file: TestMA50.both\SITTING\Subject_1.csv
# Processing file: TestMA50.both\SITTING\Subject_2.csv
# Processing file: TestMA50.both\SITTING\Subject_3.csv
# Processing file: TestMA50.both\SITTING\Subject_4.csv
# Processing file: TestMA50.both\SITTING\Subject_5.csv
# Processing file: TestMA50.both\SITTING\Subject_6.csv
# Processing file: TestMA50.both\STANDING\Subject_1.csv
# Processing file: TestMA50.both\STANDING\Subject_2.csv
# Processing file: TestMA50.both\STANDING\Subject_3.csv
# Processing file: TestMA50.both\STANDING\Subject_4.csv
# Processing file: TestMA50.both\STANDING\Subject_5.csv
# Processing file: TestMA50.both\STANDING\Subject_6.csv
# Processing file: TestMA50.both\WALKING\Subject_1.csv
# Processing file: TestMA50.both\WALKING\Subject_2.csv
# Processing file: TestMA50.both\WALKING\Subject_3.csv
# Processing file: TestMA50.both\WALKING\Subject_4.csv
# Processing file: TestMA50.both\WALKING\Subject_5.csv
# Processing file: TestMA50.both\WALKING_DOWNSTAIRS\Subject_1.csv
# Processing file: TestMA50.both\WALKING_DOWNSTAIRS\Subject_2.csv
# Processing file: TestMA50.both\WALKING_DOWNSTAIRS\Subject_3.csv
# Processing file: TestMA50.both\WALKING_DOWNSTAIRS\Subject_4.csv
# Processing file: TestMA50.both\WALKING_DOWNSTAIRS\Subject_5.csv
# Processing file: TestMA50.both\WALKING_UPSTAIRS\Subject_1.csv
# Processing file: TestMA50.both\WALKING_UPSTAIRS\Subject_2.csv
# Processing file: TestMA50.both\WALKING_UPSTAIRS\Subject_3.csv
# Processing file: TestMA50.both\WALKING_UPSTAIRS\Subject_4.csv
#
# Sign flipping complete.
#
# Adding 1 to accx for files in 'TestMA50F.acc' and saving to 'TestMA50F.acc.N'
# Processing file: TestMA50F.acc\LAYING\Subject_1.csv
# Processing file: TestMA50F.acc\LAYING\Subject_2.csv
# Processing file: TestMA50F.acc\LAYING\Subject_3.csv
# Processing file: TestMA50F.acc\LAYING\Subject_4.csv
# Processing file: TestMA50F.acc\LAYING\Subject_5.csv
# Processing file: TestMA50F.acc\LAYING\Subject_6.csv
# Processing file: TestMA50F.acc\SITTING\Subject_1.csv
# Processing file: TestMA50F.acc\SITTING\Subject_2.csv
# Processing file: TestMA50F.acc\SITTING\Subject_3.csv
# Processing file: TestMA50F.acc\SITTING\Subject_4.csv
# Processing file: TestMA50F.acc\SITTING\Subject_5.csv
# Processing file: TestMA50F.acc\SITTING\Subject_6.csv
# Processing file: TestMA50F.acc\STANDING\Subject_1.csv
# Processing file: TestMA50F.acc\STANDING\Subject_2.csv
# Processing file: TestMA50F.acc\STANDING\Subject_3.csv
# Processing file: TestMA50F.acc\STANDING\Subject_4.csv
# Processing file: TestMA50F.acc\STANDING\Subject_5.csv
# Processing file: TestMA50F.acc\STANDING\Subject_6.csv
# Processing file: TestMA50F.acc\WALKING\Subject_1.csv
# Processing file: TestMA50F.acc\WALKING\Subject_2.csv
# Processing file: TestMA50F.acc\WALKING\Subject_3.csv
# Processing file: TestMA50F.acc\WALKING\Subject_4.csv
# Processing file: TestMA50F.acc\WALKING\Subject_5.csv
# Processing file: TestMA50F.acc\WALKING_DOWNSTAIRS\Subject_1.csv
# Processing file: TestMA50F.acc\WALKING_DOWNSTAIRS\Subject_2.csv
# Processing file: TestMA50F.acc\WALKING_DOWNSTAIRS\Subject_3.csv
# Processing file: TestMA50F.acc\WALKING_DOWNSTAIRS\Subject_4.csv
# Processing file: TestMA50F.acc\WALKING_DOWNSTAIRS\Subject_5.csv
# Processing file: TestMA50F.acc\WALKING_UPSTAIRS\Subject_1.csv
# Processing file: TestMA50F.acc\WALKING_UPSTAIRS\Subject_2.csv
# Processing file: TestMA50F.acc\WALKING_UPSTAIRS\Subject_3.csv
# Processing file: TestMA50F.acc\WALKING_UPSTAIRS\Subject_4.csv
#
# Adding 1 to accx for files in 'TestMA50F.mix' and saving to 'TestMA50F.mix.N'
# Range Transforms complete.
